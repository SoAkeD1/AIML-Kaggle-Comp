# %%
import numpy as np

# %%
print(np.__version__)
# Out:
# 2.3.5

# %%
my_list=[1,2,3,4]
print(my_list)
# Out:
# [1, 2, 3, 4]

# %%
array=np.array([1,2,3,4])
print(array)
print(type(array))
# Out:
# [1 2 3 4]
# <class 'numpy.ndarray'>

# %%
array1=array*2
print(array1)
# Out:
# [2 4 6 8]
