# %%
import numpy as np

# %%
import numpy as np
array0=np.array(['A'])
array1=np.array(['A','B','C'])

array2=np.array([['A','B','C'],
                ['D','E','F'],
                ['G','H','I'],
                ])

array3=np.array([[['A','B','C'],['D','E','F'],['G','H','I']],
                [['A','B','C'],['D','E','F'],['G','H','I']],
                [['A','B','C'],['D','E','F'],['G','H',' ']]])
print(array0.ndim)
print(array1.ndim)
print(array2.ndim)
print(array3.ndim)
print(array2.shape)
print(array3[0,0,2])
word=array3[0,0,1]+array3[1,0,0]+array3[2,1,0]
print(word)
# Out:
# 1
# 1
# 2
# 3
# (3, 3)
# C
# BAD
