# %%
#L2
import pandas as pd
info={
    "name": ["rahul","anjali", "sumit"],
    "cgpa": [9.1, 8.5, 9.3],
}
df=pd.DataFrame(info)
print(df)
# Out:
#      name  cgpa
# 0   rahul   9.1
# 1  anjali   8.5
# 2   sumit   9.3

# %%
#L3
import pandas as pd
s=pd.Series([1,2,3,4,5])
print(s)
print(type(s))
print(s[2])
s1=pd.Series([10,20,30,40], index=['a','b','c','d'])
print(s1)
print(s1['c'])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# <class 'pandas.Series'>
# 3
# a    10
# b    20
# c    30
# d    40
# dtype: int64
# 30

# %%
#L4
import pandas as pd
s1=pd.Series([10,20,30,40])
s2=pd.Series([100,200,300,400])
print(s1+s2)
s1[0]=500
print(s1)
changed_s1=s1.drop(0)
print(s1)
print(changed_s1)
# Out:
# 0    110
# 1    220
# 2    330
# 3    440
# dtype: int64
# 0    500
# 1     20
# 2     30
# 3     40
# dtype: int64
# 0    500
# 1     20
# 2     30
# 3     40
# dtype: int64
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
#L5
import pandas as pd
#dataframe
info={
    "name": ["rahul","anjali", "sumit"],
    "age": [21,22,20],
    "cgpa": [9.1, 8.5, 9.3],
}
df=pd.DataFrame(info)
print(df, type(df)) 
print(df.columns)

df1=pd.DataFrame([["rahul",21,9.1],
                 ["anjali",22,8.5],
                 ["sumit",20,9.3]],
                 columns=["name","age","cgpa"])
print(df1)

import numpy as np
np_arr=np.array([[1,2,3],
                 [4,5,6],
                 ])
df2=pd.DataFrame(np_arr, columns=['a','b','c'])
print(df2)
# Out:
#      name  age  cgpa
# 0   rahul   21   9.1
# 1  anjali   22   8.5
# 2   sumit   20   9.3 <class 'pandas.core.frame.DataFrame'>
# Index(['name', 'age', 'cgpa'], dtype='object')
#      name  age  cgpa
# 0   rahul   21   9.1
# 1  anjali   22   8.5
# 2   sumit   20   9.3
#    a  b  c
# 0  1  2  3
# 1  4  5  6

# %%
#L6
import pandas as pd
#csv dataset
df=pd.read_csv('pokemon.csv')
print(df, type(df))
# Out:
#       No        Name    Type1   Type2  Height  Weight  Legendary
# 0      1   Bulbasaur    Grass  Poison     0.7     6.9          0
# 1      2     Ivysaur    Grass  Poison     1.0    13.0          0
# 2      3    Venusaur    Grass  Poison     2.0   100.0          0
# 3      4  Charmander     Fire     NaN     0.6     8.5          0
# 4      5  Charmeleon     Fire     NaN     1.1    19.0          0
# ..   ...         ...      ...     ...     ...     ...        ...
# 145  146     Moltres     Fire  Flying     2.0    60.0          1
# 146  147     Dratini   Dragon     NaN     1.8     3.3          0
# 147  148   Dragonair   Dragon     NaN     4.0    16.5          0
# 148  149   Dragonite   Dragon  Flying     2.2   210.0          0
# 149  150      Mewtwo  Psychic     NaN     2.0   122.0          1
#
# [150 rows x 7 columns] <class 'pandas.core.frame.DataFrame'>

# %%
#L7
import pandas as pd
#Methods
df=pd.read_csv('pokemon.csv')
print(df.head(10)) # Display first 10 rows ( default is 5)
print(df.tail(7)) # Display last 7 rows ( default is 5)
print(df.sample(5)) # Display random 5 rows
print(df.info()) # Display info about dataframe
print(df.describe()) # Display statistical summary of numerical columns
print(df.shape) # Display shape of dataframe (rows, columns)
print(df[df['Height'] == df['Height'].min()]) # pokemon with minimum height
print(df.columns) # Display column names
print(df.nunique()) # Display number of unique values in each column
# Out:
#    No        Name  Type1   Type2  Height  Weight  Legendary
# 0   1   Bulbasaur  Grass  Poison     0.7     6.9          0
# 1   2     Ivysaur  Grass  Poison     1.0    13.0          0
# 2   3    Venusaur  Grass  Poison     2.0   100.0          0
# 3   4  Charmander   Fire     NaN     0.6     8.5          0
# 4   5  Charmeleon   Fire     NaN     1.1    19.0          0
# 5   6   Charizard   Fire  Flying     1.7    90.5          0
# 6   7    Squirtle  Water     NaN     0.5     9.0          0
# 7   8   Wartortle  Water     NaN     1.0    22.5          0
# 8   9   Blastoise  Water     NaN     1.6    85.5          0
# 9  10    Caterpie    Bug     NaN     0.3     2.9          0
#       No       Name     Type1   Type2  Height  Weight  Legendary
# 143  144   Articuno       Ice  Flying     1.7    55.4          1
# 144  145     Zapdos  Electric  Flying     1.6    52.6          1
# 145  146    Moltres      Fire  Flying     2.0    60.0          1
# ...

# %%
#L8&L9
import pandas as pd
df=pd.read_csv('globalairquality.csv')
df.describe()

#selecting the data
print(df['city']) 
print(df[['city','aqi']])
#indexed selection:iloc and loc for label based selection
print(df.loc[2])
print(df.loc[0:2])
print(df.iloc[0:2])
print(df.iloc[0:3:1])
print(df.loc[1,"aqi"])
df.loc[0,["city","aqi"]]
#df.iloc[0,["city","aqi"]] ______ is wrong
# iloc is numerical dependent indexer
df.columns
# city is 2, and
df.iloc[0:3,2]
df.loc[0:2,["country","city","latitude","longitude"]]
df.iloc[0:3,1:5]
#cell
df.at[0,"city"]
df.iat[0,2]

cities=df["city"].copy() # copy not view if direct change kiya toh original data gaya # fukked
cities[0]='mumbai'# copy 
cities
# Out:
# 0        New York
# 1        New York
# 2        New York
# 3        New York
# 4        New York
#            ...
# 17995      Zurich
# 17996      Zurich
# 17997      Zurich
# 17998      Zurich
# 17999      Zurich
# Name: city, Length: 18000, dtype: object
#            city  aqi
# 0      New York  108
# 1      New York   90
# 2      New York   84
# 3      New York  158
# 4      New York   97
# ...         ...  ...
# 17995    Zurich  103
# 17996    Zurich  105
# 17997    Zurich  122
# 17998    Zurich   95
# 17999    Zurich   88
#
# [18000 rows x 2 columns]
# timestamp      2025-11-04 20:25:17.554219
# country                                US
# city                             New York
# latitude                           40.713
# longitude                         -74.006
# pm25                                42.25
# pm10                               82.553
# no2                                26.935
# so2                                 9.538
# ...

# %%
#L10
import pandas as pd
df=pd.read_csv('globalairquality.csv')
#filtering
df[df["aqi"]>100]
#and=& , or=| , not =~
df[(df["aqi"]>100) & (df["temperature"]>30)]
aqi_data=df[df["aqi"]>100] [["city","aqi","temperature"]]

# %%
#L11
df.query("aqi>100")
api_value =90
df.query("aqi>@api_value")
# Out:
#                         timestamp country      city  latitude  longitude  \
# 0      2025-11-04 18:25:17.554219      US  New York    40.713    -74.006
# 3      2025-11-04 21:25:17.554219      US  New York    40.713    -74.006
# 4      2025-11-04 22:25:17.554219      US  New York    40.713    -74.006
# 5      2025-11-04 23:25:17.554219      US  New York    40.713    -74.006
# 6      2025-11-05 00:25:17.554219      US  New York    40.713    -74.006
# ...                           ...     ...       ...       ...        ...
# 17994  2025-11-19 12:25:17.554219      CH    Zurich    47.377      8.542
# 17995  2025-11-19 13:25:17.554219      CH    Zurich    47.377      8.542
# 17996  2025-11-19 14:25:17.554219      CH    Zurich    47.377      8.542
# 17997  2025-11-19 15:25:17.554219      CH    Zurich    47.377      8.542
# 17998  2025-11-19 16:25:17.554219      CH    Zurich    47.377      8.542
#
#          pm25     pm10     no2    so2      o3     co  aqi  temperature  \
# ...

# %%
#L12
#cleaning
#handle missing data
import pandas as pd
df=pd.read_csv('raw_data.csv')
df.isnull()#the misssing value ---->boolean (T/f)
df.isnull().sum() # in wht column , how much null item r there?
df.dropna() # empty cell row drop
df.dropna(axis=1) # empty cell column drop
df.fillna(0)
df.fillna(100)
df["age"].fillna(0)


cleaned_data=df.copy()
age_mean=df["age"].mean()
cleaned_data["age"]=cleaned_data["age"].fillna(age_mean)
cleaned_data
df.ffill() #forward fill 
df.bfill() #backward fill
df[["country","gender"]].duplicated()
# df[specific format if any].function(specfic format of funtion)
df2=df.copy()

df.drop_duplicates()
df.drop_duplicates(inplace=True)

# %%
#L13
import pandas as pd
df=pd.read_csv('raw_data.csv')
df.dtypes
df2=df.copy()
df2=df2.fillna(0)
df2=df2["age"].astype("int64").copy()
# type casting in pandas

df2.dtypes

aqi_data=pd.read_csv("globalAirQuality.csv")
aqi_data
# Out:
#                         timestamp country      city  latitude  longitude  \
# 0      2025-11-04 18:25:17.554219      US  New York    40.713    -74.006
# 1      2025-11-04 19:25:17.554219      US  New York    40.713    -74.006
# 2      2025-11-04 20:25:17.554219      US  New York    40.713    -74.006
# 3      2025-11-04 21:25:17.554219      US  New York    40.713    -74.006
# 4      2025-11-04 22:25:17.554219      US  New York    40.713    -74.006
# ...                           ...     ...       ...       ...        ...
# 17995  2025-11-19 13:25:17.554219      CH    Zurich    47.377      8.542
# 17996  2025-11-19 14:25:17.554219      CH    Zurich    47.377      8.542
# 17997  2025-11-19 15:25:17.554219      CH    Zurich    47.377      8.542
# 17998  2025-11-19 16:25:17.554219      CH    Zurich    47.377      8.542
# 17999  2025-11-19 17:25:17.554219      CH    Zurich    47.377      8.542
#
#          pm25     pm10     no2    so2      o3     co  aqi  temperature  \
# ...

# %%
#L14
import pandas as pd
date_str=pd.Series(["2026-12-31"])
type(date_str.dtypes)

date_str=pd.Series([pd.to_datetime("2026-12-31")])
type(date_str.dtypes)

aqi_data=pd.read_csv("globalAirQuality.csv")
aqi_data["timestamp"]=pd.to_datetime(aqi_data["timestamp"])
aqi_data["timestamp"].dtype
# Out:
# dtype('<M8[ns]')

# %%
#L15
import pandas as pd
df=pd.read_csv('raw_data.csv')
df["gender"].str.lower
df["gender"].str.upper
df["gender"].str.capitalize()#oiginal data display
df["name"].str.split(" ")
#aman@gmail.com
#shrimon@gmail.com
#-----> f["name"].str.split("@")
df["country"].str.contains("usa",case=False) # case is needed to remove case senstivity
#if u r typing keeping case sentivity in mind than u dont need case function
# Out:
# 0      True
# 1      True
# 2     False
# 3      True
# 4     False
# 5     False
# 6     False
# 7       NaN
# 8      True
# 9     False
# 10     True
# Name: country, dtype: object
